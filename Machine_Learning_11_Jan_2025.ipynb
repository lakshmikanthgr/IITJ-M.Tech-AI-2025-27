# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmikanthgr/IITJ-M.Tech-AI-2025-27/blob/main/Machine_Learning_11_Jan_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Today class notes
#
# 1. E T P. Experiment, Task and Performance.
# 2. What is Machine Learning.
# 3. When do you use Machine Learning
#
#
# ## What is Machine Learning
#
#
# ## When do you use Machine Learning
# 1. Human expertize doesnot exist.
# 2. Humans can not explain their expetize
# 3. ..
#
# ![image.png](data:image/png;base64,...)
